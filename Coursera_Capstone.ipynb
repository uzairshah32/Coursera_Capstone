# %% [markdown]
# ### This notebook is made for the purpose of training on how to push the Notebook to your Github repository

# %% [markdown]
# #### Coursera Capstone Week 1

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
